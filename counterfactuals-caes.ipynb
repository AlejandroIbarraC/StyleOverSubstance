# %% [markdown]
# # CAES Dataset Notebook
# ## 2. Counterfactuals
#
# Tests related to the CAES essay dataset.
#
# ### Load dataset

# %%
import pandas as pd
# load dataset
df = pd.read_csv('caes/tagged_caes.csv')
df
# Out:
#        essay_id                                          full_text score  \
# 0             0  hola carlos ! hace mucho que no te veo hombre ...    B1
# 1             1  hola querida sara , espero que estes muy bien ...    A2
# 2             2  como estais ? ! hola amigos ! ? espero que tod...    A1
# 3             3  cuando llegué a el destino , le propuso que si...    A2
# 4             4  ¿ que tal ? un beso espero que todo va bien po...    A1
# ...         ...                                                ...   ...
# 26648     26648  buenas tardes ! 29_de_mayo_de_2019 salamanca q...    B1
# 26649     26649  tengo la seguridad de mí mismo para contener e...    B2
# 26650     26650  distinguidos señor / señra : hola , gerente . ...    B1
# 26651     26651  le escribo esta carta porque me gustaría inmen...    B2
# 26652     26652  me gusta ir a mallorca y me gusta espeicalment...    A1
#
#        word_count                 prompt_name  stance  formality  sentiment
# 0             212                 Carta amigo     0.0        1.0          1
# 1             175                 Carta amigo     0.0        1.0          0
# 2             104           Postal vacaciones     2.0        1.0          0
# 3             135           Postal vacaciones     0.0        1.0          0
# 4              80                     Familia     0.0        1.0          0
# ...           ...                         ...     ...        ...        ...
# 26648         299                 Carta amigo     0.0        1.0          0
# 26649         157          Solicitud admisión     0.0        NaN          0
# 26650         178  Reclamación compañía aérea     0.0        1.0          1
# 26651         303          Solicitud admisión     0.0        0.0          2
# 26652         155              Cambio trabajo     0.0        1.0          0
#
# [26653 rows x 8 columns]

# %% [markdown]
# ### Classifiers

# %%
import requests

# convert results list to numeric labels
stance_mapping = {
    'PRO': 0,
    'CON': 1,
    'NEUTRAL': 2
}

# calls local Ollama API Mistral instance with a defined text prompt
def query_ollama(prompt, model, temperature=0):
    response = requests.post(
        "http://localhost:11434/api/generate",
        json={"model": model,
              "prompt": prompt,
              "stream": False,
              "options": {
                  "temperature": temperature
              }
        }
    )
    return response.json()["response"].strip()

# builds stance prompt
def get_stance_prompt(essay):
    return (
        "Stance classification is the task of determining the expressed or implied opinion, or stance, of a statement"
        " toward a certain, specified target. The following statements are social media posts expressing opinions about entities.\n"
        "Each statement can either be 'PRO' or 'CON' toward their associated entity.\n"
        "entity: Atheism\n"
        "statement: Leaving Christianity enables you to love the people you once rejected. #freethinker #Christianity #SemST\n"
        "stance: PRO\n"
        "entity: Feminist Movement\n"
        "statement: Always a delight to see chest-drumming alpha males hiss and scuttle backwards up the wall when a feminist enters the room. #manly #SemST\n"
        "stance: PRO\n"
        "entity: Christianity\n"
        "statement: AlharbiF I’ll bomb anything I can get my hands on, especially if THEY aren’t christian. #graham2016 #GOP #SemST\n"
        "stance: CON\n"
        "entity: Hillary Clinton\n"
        "statement: Would you wanna be in a long term relationship with some bitch that hides her emails, & lies to your face? Then #Dontvote #SemST\n"
        "stance: CON\n"
        "Analyze the following statement and determine its stance towards the entity.\n"
        "Respond with a single word: 'PRO' or 'CON'. Only return the stance as a single word, and no other text.'\n"
        f"statement:\n{essay}\n"
        "stance:"
    )

# standalone stance classifier
def stance_classifier(text):
    prompt = get_stance_prompt(text)
    response = query_ollama(prompt, model="mistral")

    response_upper = response.upper()
    if 'CON' in response_upper:
        return stance_mapping['CON']
    elif 'PRO' in response_upper:
        return stance_mapping['PRO']
    elif 'NEUTRAL' in response_upper:
        return stance_mapping['NEUTRAL']
    else:
        return None  # unclear

# %%
from transformers import pipeline

# load model
pipe = pipeline("text-classification", model="LenDigLearn/formality-classifier-mdeberta-v3-base")

id2formality = {"formal": 0, "informal": 1, "neutral": 2}

def formality_classifier(text, threshold=0.50):
    label, score = pipe(text)[0].values()
    label_idx = id2formality[label]

    if score > threshold:
        return label_idx
    else:
        return None
# Out:
# Device set to use cpu

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model_id = "clapAI/roberta-large-multilingual-sentiment"
# Load the tokenizer and model
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForSequenceClassification.from_pretrained(model_id, torch_dtype=torch.float16)

model.to(device)
model.eval()

# Retrieve labels from the model's configuration
id2label = model.config.id2label
id2sentiment = {"positive": 0, "negative": 1, "neutral": 2}

def sentiment_classifier(text, threshold=0.90):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=512).to(device)

    # Perform inference in inference mode
    with torch.inference_mode():
        outputs = model(**inputs)
        predictions = outputs.logits.argmax(dim=-1)
    result_str = id2label[predictions.item()]
    return id2sentiment[result_str]

# %% [markdown]
# ### Generation

# %%
# dictionaries to be used in the prompt

RUBRIC = """
Here is a high level description of the knowledge that students of each CEFR level are expected to have.
- A student of level pre-A1 can give basic personal information (e.g. name, address, nationality), perhaps with the use of a dictionary.
- A student of level A1 can give information about matters of personal relevance (e.g. likes and dislikes, family, pets) using simple words/signs and basic expressions; can produce simple isolated phrases and sentences.
- A student of level A2 can produce a series of simple phrases and sentences linked with simple connectors like “and”, “but” and “because”.
- A student of level B1 can produce straightforward connected texts on a range of familiar subjects within their field of interest, by linking a series of shorter discrete elements into a linear sequence.
- A student of level B2 can produce clear, detailed texts on a variety of subjects related to their field of interest, synthesising and evaluating information and arguments from a number of sources.
- A student of level C1 can produce clear, well-structured texts of complex subjects, underlining the relevant issues, expanding and supporting points of view at some length with subsidiary points, reasons and relevant examples, and rounding off with an appropriate conclusion; can employ the structure, vocabulary and register of genres, varying the tone, style and structure in an appropriate way for the target reader.
- A student of level C2 can write clear, smoothly flowing, complex texts in an appropriate and effective style and a logical structure which helps the reader identify significant points.
"""

stance_opposite = {
    'PRO': 'CON',
    'CON': 'PRO',
}

formality_opposite = {
    'FORMAL': 'INFORMAL',
    'INFORMAL': 'FORMAL'
}

sentiment_opposite = {
    'POSITIVE': 'NEGATIVE',
    'NEGATIVE': 'POSITIVE'
}

attribute_context = {
    'stance': (
        "In a PRO stance, the author clearly supports the topic by providing strong reasons in favor of it, emphasizing benefits, positives, and supportive arguments.\n"
        "In a CON stance, the author clearly opposes the topic, focusing on drawbacks, risks, or negative consequences.\n"
        "Switching stance requires presenting the OPPOSITE arguments.\n"
    ),
    'formality': (
        "FORMAL writing is structured and objective. It uses academic language, avoids contractions (like 'don't' or 'can't'), and avoids casual expressions.\n"
        "It favors complex sentences, third-person point of view, and professional tone.\n"
        "INFORMAL writing is conversational, uses contractions and casual language, favors first-person or second-person, and may include slang or simple sentence structures.\n"
        "To change from FORMAL to INFORMAL, make the writing sound more like spoken language. Use really simple, repeated words and structures, expressions. Use contractions and slang terms. \n"
        "To change from INFORMAL to FORMAL, eliminate contractions, use more precise vocabulary, and avoid casual phrasing.\n"
    ),
    'sentiment': (
        "POSITIVE sentiment expresses approval, optimism, or positive feelings.\n"
        "NEGATIVE sentiment expresses disapproval, criticism, or negative feelings.\n"
    )
}

# function to build the counterfactual prompt to be fed to the LLM
def get_counterfactual_prompt(text, attribute, original_label, og_score):
    if attribute == 'stance':
        opposite_label = stance_opposite.get(original_label, "UNKNOWN")
        instruction = f"the current stance is {original_label}. Change it to {opposite_label}"
    elif attribute == 'formality':
        opposite_label = formality_opposite.get(original_label, "UNKNOWN")
        instruction = f"the current style is '{original_label}'. Change it to {opposite_label}."
    elif attribute == 'sentiment':
        opposite_label = sentiment_opposite.get(original_label, "UNKNOWN")
        instruction = f"the current sentiment is '{original_label}'. Change it to {opposite_label}."
    else:
        instruction = "Unknown attribute."

    return (
        "You are a skilled editor. Your task is to rewrite the following essay carefully."
        f"Keep the structure, arguments, and topic the same, but {instruction}. "
        f"Context:\n{attribute_context[attribute]}\n\n"
        "Do not add new ideas or remove key points. Keep the length and organization similar.\n"
        "Keep the same level of language proficiency from the original essay, including misspellings, punctuation and capitalization.\n"
        f"This essay has a level of {og_score} according to the rubric description. Your rewriting must meet the exact criteria as the rubric details for a score of {og_score}. The marking rubric is defined as follows:\n{RUBRIC}\n\n"
        "Respond with the rewritten essay only. Write your answer in Spanish\n\n"
        f"Original essay:\n{text}\n"
        f"Rewritten essay:"
    )

# generates a counterfactual given text, attribute, original label and the essay score
def generate_counterfactual(text, attribute, original_label, og_score):
    prompt = get_counterfactual_prompt(text, attribute, original_label, og_score)
    response = query_ollama(prompt, model="gemma3:12b", temperature=0.7)
    return response

# %%
import random

# generates x amount of counterfactuals and validates them using the given attribute classifier.
# essays are discarded if they do not align with correct classification.
# uses stratified sampling by holistic_essay_score attribute
def collect_validated_flips(
    df,
    attribute: str,                   # 'stance', 'formality', or 'sentiment'
    from_class: int,                  # e.g., 0 (for PRO)
    classifier_fn=None,               # e.g., stance_classifier
    label_mapping=None,               # e.g., {'PRO': 0, 'CON': 1, 'NEUTRAL': 2}
    prefix="ST",                      # e.g., 'ST'
    target_count=100
):

    # reverse the label mapping
    reverse_label_mapping = {v: k for k, v in label_mapping.items()}

    from_label = reverse_label_mapping[from_class]
    to_label = {
        'stance': stance_opposite,
        'formality': formality_opposite,
        'sentiment': sentiment_opposite
    }[attribute][from_label]
    to_class = label_mapping[to_label]

    successful_flips = []

    # stratified ssampling by score
    score_bins = {score: group.index.tolist() for score, group in df.groupby('score')}
    bin_targets = {score: max(1, int(len(indices) / len(df) * target_count)) for score, indices in score_bins.items()}

    total_flips = 0 # count total flips
    total_attempts = 1
    for score, indices in score_bins.items():
        if total_flips >= target_count:
            print(f"Done. Total flips is {total_flips} out of {target_count}")
            break

        random.shuffle(indices)
        sample_count = 0

        for idx in indices:
            if sample_count >= bin_targets[score]:
                break

            row = df.loc[idx]
            if row[attribute] != from_class:
                continue

            original_text = row['full_text']
            essay_code_original = f"{idx}-O"
            og_score = row['score']

            # generate counterfactual
            print(f"----- Attempt: {total_attempts} -----")
            try:
                print(f"Generating counterfactual... Attribute: {attribute}. {from_label} -> {to_label}")
                flipped_text = generate_counterfactual(original_text, attribute, from_label, og_score)
                print("Counterfactual generated.")
                #print(f"Original text:\n\n{original_text}\n\nFlipped text:\n\n{flipped_text}")
                new_label = classifier_fn(flipped_text)
                print(f"New label: {reverse_label_mapping[new_label]}")
            except Exception as e:
                print(f"[!] Error at idx {idx}: {e}")
                continue

            print(f"Flip Attempt: {from_label} → {to_label} | Classified as: {new_label}")

            if new_label == to_class:
                print("✓ - Correctly generated!")
                essay_code_cf = f"{idx}-C{prefix}"

                successful_flips.append({
                    "essay_code": essay_code_original,
                    "full_text": original_text,
                    "attribute": attribute,
                    "label": from_class,
                    "score_og": row['score']
                })

                successful_flips.append({
                    "essay_code": essay_code_cf,
                    "full_text": flipped_text,
                    "attribute": attribute,
                    "label": to_class,
                    "score_og": row['score']
                })

                sample_count += 1
                total_flips += 1
            else:
                print("X - Incorrectly generated!")
            total_attempts += 1

            if len(successful_flips) >= target_count * 2:
                break

    print("---------------------------------------")
    print(f"Generated {total_flips} counterfactuals with {total_attempts - 1} attempts.")

    # second pass to fill counterfactuals if target not reached
    if total_flips < target_count:
        print(f"\nSecond pass: filling {target_count - total_flips} missing flips...")

        remaining_indices = df[df[attribute] == from_class].index.tolist()
        random.shuffle(remaining_indices)

        for idx in remaining_indices:
            if total_flips >= target_count:
                break

            row = df.loc[idx]
            original_text = row['full_text']
            essay_code_original = f"{idx}-O"
            og_score = row['score']

            print(f"----- Attempt: {total_attempts} -----")
            try:
                print(f"Generating counterfactual... Attribute: {attribute}. {from_label} -> {to_label}")
                flipped_text = generate_counterfactual(original_text, attribute, from_label, og_score)
                print("Counterfactual generated.")
                new_label = classifier_fn(flipped_text)
                print(f"New label: {reverse_label_mapping[new_label]}")
            except Exception as e:
                print(f"[!] Error at idx {idx}: {e}")
                continue

            print(f"Flip Attempt: {from_label} → {to_label} | Classified as: {new_label}")

            if new_label == to_class:
                print("✓ - Correctly generated!")
                essay_code_cf = f"{idx}-C{prefix}"

                successful_flips.append({
                    "essay_code": essay_code_original,
                    "full_text": original_text,
                    "attribute": attribute,
                    "label": from_class,
                    "score_og": row['score']
                })

                successful_flips.append({
                    "essay_code": essay_code_cf,
                    "full_text": flipped_text,
                    "attribute": attribute,
                    "label": to_class,
                    "score_og": row['score']
                })

                total_flips += 1
            else:
                print("X - Incorrectly generated!")
            total_attempts += 1

    print(f"Generated {total_flips} counterfactuals")

    return pd.DataFrame(successful_flips)

# %%
# generate PRO -> CON flipped stance counterfactuals

stance_pro_to_con_df = collect_validated_flips(
    df=df,
    attribute="stance",
    from_class=0,  # PRO
    classifier_fn=stance_classifier,
    label_mapping={"PRO": 0, "CON": 1, "NEUTRAL": 2},
    prefix="ST",
    target_count=100
)

stance_pro_to_con_df
# Out:
# ----- Attempt: 1 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: PRO → CON | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 2 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 3 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: PRO → CON | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 4 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 5 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 6 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 7 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: PRO
# Flip Attempt: PRO → CON | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 8 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 9 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 10 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 11 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 12 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: PRO → CON | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 13 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: PRO → CON | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 14 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 15 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 16 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: PRO
# Flip Attempt: PRO → CON | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 17 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: PRO
# Flip Attempt: PRO → CON | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 18 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: PRO
# Flip Attempt: PRO → CON | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 19 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: PRO → CON | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 20 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: PRO
# Flip Attempt: PRO → CON | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 21 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 22 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# [!] Error at idx 4746: None
# ----- Attempt: 22 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: PRO
# Flip Attempt: PRO → CON | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 23 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 24 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: PRO → CON | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 25 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 26 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 27 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: PRO → CON | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 28 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: PRO → CON | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 29 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: PRO → CON | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 30 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: PRO → CON | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 31 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 32 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 33 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 34 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 35 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: PRO → CON | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 36 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 37 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 38 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 39 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 40 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 41 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 42 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 43 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: PRO → CON | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 44 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 45 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 46 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 47 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 48 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: PRO → CON | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 49 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 50 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 51 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 52 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 53 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 54 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 55 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: PRO
# Flip Attempt: PRO → CON | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 56 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# [!] Error at idx 2253: None
# ----- Attempt: 56 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 57 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 58 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 59 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 60 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 61 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 62 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 63 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 64 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 65 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 66 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: PRO
# Flip Attempt: PRO → CON | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 67 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 68 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 69 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 70 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 71 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 72 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: PRO
# Flip Attempt: PRO → CON | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 73 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: PRO
# Flip Attempt: PRO → CON | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 74 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 75 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 76 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 77 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 78 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 79 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 80 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 81 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 82 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: PRO → CON | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 83 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 84 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 85 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 86 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: PRO
# Flip Attempt: PRO → CON | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 87 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 88 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 89 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 90 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 91 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 92 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: PRO
# Flip Attempt: PRO → CON | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 93 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 94 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: PRO
# Flip Attempt: PRO → CON | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 95 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: PRO
# Flip Attempt: PRO → CON | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 96 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 97 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: PRO → CON | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 98 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 99 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 100 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 101 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 102 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: PRO → CON | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 103 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 104 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: PRO → CON | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 105 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 106 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 107 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: PRO
# Flip Attempt: PRO → CON | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 108 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: PRO
# Flip Attempt: PRO → CON | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 109 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: PRO
# Flip Attempt: PRO → CON | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 110 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 111 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 112 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: PRO → CON | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 113 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 114 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 115 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 116 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 117 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 118 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: PRO → CON | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 119 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 120 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: PRO → CON | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 121 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: PRO → CON | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 122 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 123 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 124 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 125 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 126 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 127 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 128 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 129 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 130 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 131 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 132 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 133 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 134 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 135 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ---------------------------------------
# Generated 97 counterfactuals with 135 attempts.
#
# Second pass: filling 3 missing flips...
# ----- Attempt: 136 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 137 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: PRO
# Flip Attempt: PRO → CON | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 138 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 139 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: PRO → CON | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 140 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# Generated 100 counterfactuals
#     essay_code                                          full_text attribute  \
# 0       1364-O  querido compañero : hola , me llamo elene , so...    stance
# 1     1364-CST  Querido compañero: Hola, me llamo Elene, soy u...    stance
# 2       6849-O  voy a explicar+un_poco explicar+un_poco mas so...    stance
# 3     6849-CST  voy a explicar un poco, explicar un poco mas s...    stance
# 4      11790-O  es es una persona estupendo ! después quiero i...    stance
# ..         ...                                                ...       ...
# 195   3559-CST  quiero presentar os mi hermana mayor. se llama...    stance
# 196    11228-O  sr. coordenador de el postgrado de lengua y li...    stance
# 197  11228-CST  Sr. Coordinador de el postgrado de lengua y li...    stance
# 198    13708-O  muy señores : me llamo chantal_tabanji , soy l...    stance
# 199  13708-CST  muy señores : me llamo chantal_tabanji , soy l...    stance
#
#      label score_og
# 0        0       A1
# 1        1       A1
# 2        0       A1
# 3        1       A1
# 4        0       A1
# ..     ...      ...
# 195      1       A2
# 196      0       B2
# 197      1       B2
# 198      0       B2
# 199      1       B2
#
# [200 rows x 5 columns]

# %%
# generate CON -> PRO flipped stance counterfactuals

stance_con_to_pro_df = collect_validated_flips(
    df=df,
    attribute="stance",
    from_class=1,  # CON
    classifier_fn=stance_classifier,
    label_mapping={"PRO": 0, "CON": 1, "NEUTRAL": 2},
    prefix="ST",
    target_count=100
)

stance_con_to_pro_df
# Out:
# ----- Attempt: 1 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 2 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: CON → PRO | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 3 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 4 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 5 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 6 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 7 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 8 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 9 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: CON → PRO | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 10 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 11 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 12 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 13 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 14 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 15 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 16 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 17 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: CON → PRO | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 18 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 19 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: CON → PRO | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 20 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: CON → PRO | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 21 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 22 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 23 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 24 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: CON → PRO | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 25 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 26 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: CON → PRO | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 27 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 28 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 29 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 30 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 31 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 32 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 33 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 34 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 35 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 36 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 37 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 38 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: CON → PRO | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 39 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 40 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 41 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 42 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 43 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 44 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 45 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 46 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: CON → PRO | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 47 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 48 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 49 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 50 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 51 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: CON → PRO | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 52 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 53 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 54 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 55 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 56 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 57 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 58 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: CON → PRO | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 59 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: CON → PRO | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 60 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: CON → PRO | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 61 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 62 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 63 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 64 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 65 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 66 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 67 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 68 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 69 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 70 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 71 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 72 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 73 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 74 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: CON → PRO | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 75 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 76 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 77 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 78 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 79 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 80 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 81 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 82 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 83 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: CON → PRO | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 84 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# [!] Error at idx 6096: None
# ----- Attempt: 84 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 85 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 86 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 87 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: CON → PRO | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 88 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 89 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 90 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 91 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 92 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 93 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 94 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 95 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: CON → PRO | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 96 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# [!] Error at idx 12946: None
# ----- Attempt: 96 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 97 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 98 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 99 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 100 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 101 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 102 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 103 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 104 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 105 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 106 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 107 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 108 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 109 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 110 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 111 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 112 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 113 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 114 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 115 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 116 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 117 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 118 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 119 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: CON → PRO | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 120 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 121 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 122 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 123 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 124 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 125 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 126 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 127 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 128 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 129 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 130 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 131 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 132 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 133 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 134 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 135 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 136 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ---------------------------------------
# Generated 97 counterfactuals with 136 attempts.
#
# Second pass: filling 3 missing flips...
# ----- Attempt: 137 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 138 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 139 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# Generated 100 counterfactuals
#     essay_code                                          full_text attribute  \
# 0      20565-O  ! ¿ qué tal ? voy te presentar mi familia . es...    stance
# 1    20565-CST  ! ¿ qué tal ? voy te presentar mi familia . es...    stance
# 2      21010-O  en carnaval de ese año ( 2011 ) bruno mi amigo...    stance
# 3    21010-CST  en carnaval de ese año ( 2011 ) bruno mi amigo...    stance
# 4       5103-O  janete , mi hermana más vieja es casada con in...    stance
# ..         ...                                                ...       ...
# 195  22257-CST  hola chicas! durante las ultimas vaciones fui ...    stance
# 196     6476-O  fumar en lugares públicos creo en la libertad ...    stance
# 197   6476-CST  Fumar en lugares públicos creo en la libertad ...    stance
# 198    12801-O  18_de_noviembre_de_2011 desde la cuidad de san...    stance
# 199  12801-CST  18_de_noviembre_de_2011 desde la cuidad de san...    stance
#
#      label score_og
# 0        1       A1
# 1        0       A1
# 2        1       A1
# 3        0       A1
# 4        1       A1
# ..     ...      ...
# 195      0       A2
# 196      1       B2
# 197      0       B2
# 198      1       C1
# 199      0       C1
#
# [200 rows x 5 columns]

# %%
# generate POSITIVE -> NEGATIVE flipped sentiment counterfactuals

sentiment_positive_to_negative_df = collect_validated_flips(
    df=df,
    attribute="sentiment",
    from_class=0,  # POSITIVE
    classifier_fn=sentiment_classifier,
    label_mapping={"POSITIVE": 0, "NEGATIVE": 1, "NEUTRAL": 2},
    prefix="SE",
    target_count=100
)

sentiment_positive_to_negative_df
# Out:
# ----- Attempt: 1 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 2 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 3 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 4 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 5 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 6 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 7 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 8 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 9 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 10 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 11 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 12 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 13 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 14 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 15 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 16 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 17 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 18 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 19 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 20 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 21 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 22 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 23 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 24 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 25 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 26 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 27 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 28 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 29 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 30 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 31 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 32 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 33 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 34 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 35 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 36 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 37 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 38 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 39 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 40 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 41 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 42 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 43 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 44 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 45 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 46 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 47 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 48 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 49 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 50 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 51 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 52 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 53 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 54 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 55 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 56 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 57 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 58 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 59 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 60 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 61 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 62 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 63 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 64 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 65 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 66 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 67 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 68 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 69 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 70 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 71 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 72 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 73 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 74 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 75 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 76 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 77 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 78 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 79 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 80 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 81 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 82 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 83 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 84 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 85 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 86 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 87 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 88 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 89 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 90 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 91 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 92 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 93 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 94 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 95 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 96 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 97 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 98 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 99 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 100 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 101 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 102 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 103 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 104 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 105 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 106 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ---------------------------------------
# Generated 97 counterfactuals with 106 attempts.
#
# Second pass: filling 3 missing flips...
# ----- Attempt: 107 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 108 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 109 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# Generated 100 counterfactuals
#     essay_code                                          full_text  attribute  \
# 0      21844-O  compañeros de trabajo soy juan el nuevo direct...  sentiment
# 1    21844-CSE  compañeros de trabajo soy juan el nuevo direct...  sentiment
# 2      18327-O  ¡ hola laura ! como estas ? soy haifa tu compa...  sentiment
# 3    18327-CSE  ¡ hola laura ! como estas ? soy haifa tu compa...  sentiment
# 4      10233-O  ! estoy muy contente con eso ! para que me con...  sentiment
# ..         ...                                                ...        ...
# 195  16550-CSE  salvador_dali nacio el siglo pasado en figuere...  sentiment
# 196    18238-O  buenas tardes . me llamo sérgio_francisco y le...  sentiment
# 197  18238-CSE  buenas tardes . me llamo sérgio_francisco y le...  sentiment
# 198    16203-O  la última vez que vi una película fue hace una...  sentiment
# 199  16203-CSE  la última vez que vi una película fue hace una...  sentiment
#
#      label score_og
# 0        0       A1
# 1        1       A1
# 2        0       A1
# 3        1       A1
# 4        0       A1
# ..     ...      ...
# 195      1       A2
# 196      0       A2
# 197      1       A2
# 198      0       C1
# 199      1       C1
#
# [200 rows x 5 columns]

# %%
# generate NEGATIVE -> POSITIVE flipped sentiment counterfactuals

sentiment_negative_to_positive_df = collect_validated_flips(
    df=df,
    attribute="sentiment",
    from_class=1,  # NEGATIVE
    classifier_fn=sentiment_classifier,
    label_mapping={"POSITIVE": 0, "NEGATIVE": 1, "NEUTRAL": 2},
    prefix="SE",
    target_count=100
)

sentiment_negative_to_positive_df
# Out:
# ----- Attempt: 1 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 2 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 3 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 4 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 5 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 6 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 7 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 8 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 9 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 10 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 11 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 12 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 13 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 14 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 15 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 16 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 17 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 18 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 19 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 20 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 21 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 22 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 23 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 24 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 25 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 26 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 27 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 28 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 29 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 30 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 31 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 32 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 33 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 34 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 35 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 36 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 37 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 38 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 39 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 40 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 41 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 42 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 43 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 44 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 45 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 46 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 47 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 48 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 49 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 50 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 51 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 52 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 53 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 54 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 55 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 56 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 57 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 58 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 59 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 60 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 61 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 62 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 63 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 64 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 65 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 66 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 67 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 68 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 69 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 70 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 71 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 72 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 73 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 74 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 75 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 76 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 77 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 78 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 79 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 80 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 81 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 82 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 83 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 84 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 85 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 86 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 87 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 88 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 89 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 90 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 91 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 92 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 93 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 94 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 95 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 96 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 97 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 98 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 99 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 100 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 101 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 102 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 103 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 104 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 105 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 106 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 107 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 108 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 109 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 110 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 111 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 112 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 113 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 114 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 115 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 116 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 117 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 118 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 119 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 120 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 121 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 122 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 123 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 124 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 125 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 126 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 127 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 128 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 129 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 130 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 131 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 132 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 133 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 134 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 135 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 136 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 137 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 138 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 139 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 140 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 141 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 142 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 143 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 144 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ---------------------------------------
# Generated 97 counterfactuals with 144 attempts.
#
# Second pass: filling 3 missing flips...
# ----- Attempt: 145 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 146 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 147 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 148 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# Generated 100 counterfactuals
#     essay_code                                          full_text  attribute  \
# 0      26473-O  hola , mi padres están muertos . bruno vive en...  sentiment
# 1    26473-CSE  Hola, mi padres están vivos y muy bien. Bruno ...  sentiment
# 2          6-O  acudí a su compañía la dirección de la cual ví...  sentiment
# 3        6-CSE  acudí a su compañía la cual ví en una página w...  sentiment
# 4      22659-O  caro , " randômico " ! , bueno ... mi padre , ...  sentiment
# ..         ...                                                ...        ...
# 195  17025-CSE  yo adoro mi amiga, yuki. es de la prefectura d...  sentiment
# 196    11419-O  en los ultimos años , muchos paises han proheb...  sentiment
# 197  11419-CSE  en los últimos años, muchos países han promovi...  sentiment
# 198     1611-O  en_meados_de junio_de_2010 , unos amigos mío y...  sentiment
# 199   1611-CSE  en_meados_de junio_de_2010, unos amigos mío y ...  sentiment
#
#      label score_og
# 0        1       A1
# 1        0       A1
# 2        1       A1
# 3        0       A1
# 4        1       A1
# ..     ...      ...
# 195      0       A2
# 196      1       B2
# 197      0       B2
# 198      1       B1
# 199      0       B1
#
# [200 rows x 5 columns]

# %%
# generate FORMAL -> INFORMAL flipped formality counterfactuals

formality_formal_to_informal_df = collect_validated_flips(
    df=df,
    attribute="formality",
    from_class=0,  # FORMAL
    classifier_fn=formality_classifier,
    label_mapping={"FORMAL": 0, "INFORMAL": 1, "NEUTRAL": 2},
    prefix="FO",
    target_count=100
)

formality_formal_to_informal_df
# Out:
# ----- Attempt: 1 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 2 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 3 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 4 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# [!] Error at idx 14619: None
# ----- Attempt: 4 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 5 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 6 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 7 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 8 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# [!] Error at idx 1581: None
# ----- Attempt: 8 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 9 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 10 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 11 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 12 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 13 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 14 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# [!] Error at idx 15441: None
# ----- Attempt: 14 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 15 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 16 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 17 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# [!] Error at idx 13938: None
# ----- Attempt: 17 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 18 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 19 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 20 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 21 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 22 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 23 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 24 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 25 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 26 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 27 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 28 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 29 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# [!] Error at idx 21802: None
# ----- Attempt: 29 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 30 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 31 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 32 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 33 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 34 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 35 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 36 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 37 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# [!] Error at idx 18258: None
# ----- Attempt: 37 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# [!] Error at idx 23915: None
# ----- Attempt: 37 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 38 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 39 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 40 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 41 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 42 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 43 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 44 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 45 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 46 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 47 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 48 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 49 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 50 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 51 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 52 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 53 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 54 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 55 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 56 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 57 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 58 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 59 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 60 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 61 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 62 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 63 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 64 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 65 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 66 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 67 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 68 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 69 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 70 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 71 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 72 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 73 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 74 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 75 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 76 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 77 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 78 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 79 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 80 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 81 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 82 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 83 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 84 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 85 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 86 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 87 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 88 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 89 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 90 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 91 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 92 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 93 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 94 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 95 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 96 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 97 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 98 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 99 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 100 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 101 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 102 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 103 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 104 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 105 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 106 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 107 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 108 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 109 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 110 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 111 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 112 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 113 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 114 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 115 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 116 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 117 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 118 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 119 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 120 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 121 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 122 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 123 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 124 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 125 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 126 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 127 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 128 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 129 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 130 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# [!] Error at idx 20097: None
# ----- Attempt: 130 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 131 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 132 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ---------------------------------------
# Generated 97 counterfactuals with 132 attempts.
#
# Second pass: filling 3 missing flips...
# ----- Attempt: 133 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 134 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 135 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 136 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 137 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# Generated 100 counterfactuals
#     essay_code                                          full_text  attribute  \
# 0       2697-O  hola , buenas tardes . mi nombre es daniela y ...  formality
# 1     2697-CFO  hola, buenas tardes. soy daniela y te escribo ...  formality
# 2       9067-O  estimada amiga , es con mucho gusto que te esc...  formality
# 3     9067-CFO  Querida amiga,\n\n¡Qué guay escribirte! Quiero...  formality
# 4       1281-O  ¡ hola mi amigo ! que tal , ¿ bien ? pues , te...  formality
# ..         ...                                                ...        ...
# 195  10745-CFO  Hola,\n\nSoy Luiz Ricardo, cliente de su compa...  formality
# 196     6695-O  estimado sr. , sra , contacto ustedes hoy_en_d...  formality
# 197   6695-CFO  querido señor/señora,\n\nles escribo hoy para ...  formality
# 198    21494-O  estimado xxx : le escribo este correo después ...  formality
# 199  21494-CFO  Hola xxx:\n\nTe escribo este correo porque ya ...  formality
#
#      label score_og
# 0        0       A1
# 1        1       A1
# 2        0       A1
# 3        1       A1
# 4        0       A1
# ..     ...      ...
# 195      1       C1
# 196      0       B1
# 197      1       B1
# 198      0       C1
# 199      1       C1
#
# [200 rows x 5 columns]

# %%
# generate INFORMAL -> FORMAL flipped formality counterfactuals

formality_informal_to_formal_df = collect_validated_flips(
    df=df,
    attribute="formality",
    from_class=1,  # INFORMAL
    classifier_fn=formality_classifier,
    label_mapping={"FORMAL": 0, "INFORMAL": 1, "NEUTRAL": 2},
    prefix="FO",
    target_count=100
)

formality_informal_to_formal_df
# Out:
# ----- Attempt: 1 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 2 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# [!] Error at idx 10205: None
# ----- Attempt: 2 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 3 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 4 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 5 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 6 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# [!] Error at idx 6471: None
# ----- Attempt: 6 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 7 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 8 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 9 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 10 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 11 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 12 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 13 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 14 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 15 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 16 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# [!] Error at idx 16715: None
# ----- Attempt: 16 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 17 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 18 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 19 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# [!] Error at idx 1172: None
# ----- Attempt: 19 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# [!] Error at idx 20822: None
# ----- Attempt: 19 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 20 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 21 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 22 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 23 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 24 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 25 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 26 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 27 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 28 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 29 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 30 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 31 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 32 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 33 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 34 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 35 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 36 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 37 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 38 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 39 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 40 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 41 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 42 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 43 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# [!] Error at idx 14595: None
# ----- Attempt: 43 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 44 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 45 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 46 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 47 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 48 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 49 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 50 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 51 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 52 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 53 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 54 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 55 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 56 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 57 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# [!] Error at idx 1052: None
# ----- Attempt: 57 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# [!] Error at idx 10451: None
# ----- Attempt: 57 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 58 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 59 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 60 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 61 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 62 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 63 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 64 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 65 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 66 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 67 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 68 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 69 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 70 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 71 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 72 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 73 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 74 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 75 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 76 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 77 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 78 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 79 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 80 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 81 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 82 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 83 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 84 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 85 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 86 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 87 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 88 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 89 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 90 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 91 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 92 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 93 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 94 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 95 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 96 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 97 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 98 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 99 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 100 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 101 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 102 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 103 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 104 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 105 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 106 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 107 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 108 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 109 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 110 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 111 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 112 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 113 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 114 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 115 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 116 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 117 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 118 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 119 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 120 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 121 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 122 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 123 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 124 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 125 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 126 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 127 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 128 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 129 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 130 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 131 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 132 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 133 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 134 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 135 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 136 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 137 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 138 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 139 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 140 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 141 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 142 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 143 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 144 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 145 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 146 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 147 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 148 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 149 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 150 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 151 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 152 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 153 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 154 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 155 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 156 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 157 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 158 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 159 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 160 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 161 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 162 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 163 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 164 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# [!] Error at idx 1412: None
# ----- Attempt: 164 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 165 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 166 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 167 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 168 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# [!] Error at idx 12196: None
# ----- Attempt: 168 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 169 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 170 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 171 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 172 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 173 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 174 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 175 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 176 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 177 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 178 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 179 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 180 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 181 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 182 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 183 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 184 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 185 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 186 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 187 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# [!] Error at idx 7738: None
# ----- Attempt: 187 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 188 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 189 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 190 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 191 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 192 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 193 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 194 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 195 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 196 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 197 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 198 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 199 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 200 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 201 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 202 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 203 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 204 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# [!] Error at idx 26106: None
# ----- Attempt: 204 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 205 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 206 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 207 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 208 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 209 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 210 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 211 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 212 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 213 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# ...
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 233 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 234 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# [!] Error at idx 18436: None
# ----- Attempt: 234 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 235 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 236 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 237 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 238 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 239 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 240 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 241 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 242 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 243 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 244 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 245 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 246 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 247 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 248 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 249 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 250 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 251 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 252 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 253 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 254 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 255 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 256 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 257 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 258 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 259 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 260 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 261 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# [!] Error at idx 14288: None
# ----- Attempt: 261 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 262 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 263 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 264 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# [!] Error at idx 10900: None
# ----- Attempt: 264 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 265 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 266 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 267 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 268 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 269 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 270 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 271 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 272 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 273 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 274 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 275 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 276 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 277 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 278 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 279 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 280 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 281 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 282 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 283 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 284 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 285 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# [!] Error at idx 2344: None
# ----- Attempt: 285 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 286 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 287 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 288 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 289 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 290 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 291 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ---------------------------------------
# Generated 97 counterfactuals with 291 attempts.
#
# Second pass: filling 3 missing flips...
# ----- Attempt: 292 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 293 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 294 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 295 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 296 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# Generated 100 counterfactuals
#     essay_code                                          full_text  attribute  \
# 0      14460-O  hola , me nombre es mirna yo soy casada y tego...  formality
# 1    14460-CFO  Hola, mi nombre es Mirna. Yo soy casada y teng...  formality
# 2      25416-O  hola ! como estas ! yo entiendo de tu lettre q...  formality
# 3    25416-CFO  Hola. ¿Cómo está usted? Entiendo de su carta q...  formality
# 4      15452-O  hola pedro , mi familia vive un_poco lejo ahor...  formality
# ..         ...                                                ...        ...
# 195   9216-CFO  Estimada profesora Marcela,\n\nLe escribo con ...  formality
# 196    10420-O  me gustaría que me diese las informaciones nec...  formality
# 197  10420-CFO  Agradecería que me proporcionara la informació...  formality
# 198    21969-O  lo que escribo ahora es acerca_de la persona d...  formality
# 199  21969-CFO  Lo que escribo ahora es sobre la persona de mi...  formality
#
#      label score_og
# 0        1       A1
# 1        0       A1
# 2        1       A1
# 3        0       A1
# 4        1       A1
# ..     ...      ...
# 195      0       A2
# 196      1       B2
# 197      0       B2
# 198      1       A2
# 199      0       A2
#
# [200 rows x 5 columns]

# %%
import os

# save counterfactuals to its folder
os.makedirs("counterfactuals/caes", exist_ok=True)

stance_pro_to_con_df.to_csv("counterfactuals/caes/stance_pro_to_con.csv", index=False)
stance_con_to_pro_df.to_csv("counterfactuals/caes/stance_con_to_pro.csv", index=False)

sentiment_positive_to_negative_df.to_csv("counterfactuals/caes/sentiment_positive_to_negative.csv", index=False)
sentiment_negative_to_positive_df.to_csv("counterfactuals/caes/sentiment_negative_to_positive.csv", index=False)

formality_formal_to_informal_df.to_csv("counterfactuals/caes/formality_formal_to_informal.csv", index=False)
formality_informal_to_formal_df.to_csv("counterfactuals/caes/formality_informal_to_formal.csv", index=False)
