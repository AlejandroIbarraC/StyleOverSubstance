# %% [markdown]
# # PERSUADE 2.0 Dataset Notebook
# ## 2. Counterfactuals
#
# Tests related to the PERSUADE 2.0 essay dataset.
#
# ### Load dataset

# %%
import pandas as pd
# load dataset
df = pd.read_csv('persuade/tagged_persuade.csv')
df
# Out:
#       essay_id_comp                                          full_text  \
# 0      423A1CA112E2  phones\r\n\r\nmodern humans today are always o...
# 1      BC75783F96E3  this essay will explain if drivers should or s...
# 2      74C8BC7417DE  driving while the use of cellular devices\r\n\...
# 3      A8445CABFECE  phones & driving\r\n\r\ndrivers should not be ...
# 4      6B4F7A0165B9  cell phone operation while driving\r\n\r\nthe ...
# ...             ...                                                ...
# 25073  AFEC37C2D43F  there has been at least one point in everyone'...
# 25074  D46BCB48440A  when people ask for advice,they sometimes talk...
# 25075  0FB0700DAF44  during a group project, have you ever asked a ...
# 25076  D72CB1C11673  making choices in life can be very difficult. ...
# 25077  DF920E0A7337  have you ever asked more than one person for h...
#
#        holistic_essay_score  word_count                prompt_name  stance  \
# 0                         3         378         Phones and driving     2.0
# 1                         4         432         Phones and driving     1.0
# 2                         2         179         Phones and driving     1.0
# 3                         3         221         Phones and driving     1.0
# 4                         4         334         Phones and driving     1.0
# ...                     ...         ...                        ...     ...
# 25073                     5         547  Seeking multiple opinions     2.0
# 25074                     4         373  Seeking multiple opinions     0.0
# 25075                     4         631  Seeking multiple opinions     0.0
# 25076                     4         417  Seeking multiple opinions     0.0
# 25077                     4         706  Seeking multiple opinions     0.0
#
#        formality  sentiment
# 0              0        0.0
# 1              0        0.0
# 2              0        1.0
# 3              1        1.0
# 4              0        1.0
# ...          ...        ...
# 25073          0        1.0
# 25074          1        0.0
# 25075          0        0.0
# 25076          0        0.0
# 25077          0        0.0
#
# [25078 rows x 8 columns]

# %% [markdown]
# ### Classifiers

# %%
import requests

# convert results list to numeric labels
stance_mapping = {
    'PRO': 0,
    'CON': 1,
    'NEUTRAL': 2
}

# calls local Ollama API Mistral instance with a defined text prompt
def query_ollama(prompt, model, temperature=0):
    response = requests.post(
        "http://localhost:11434/api/generate",
        json={"model": model,
              "prompt": prompt,
              "stream": False,
              "options": {
                  "temperature": temperature
              }
        }
    )
    return response.json()["response"].strip()

# builds stance prompt
def get_stance_prompt(essay):
    return (
        "Stance classification is the task of determining the expressed or implied opinion, or stance, of a statement"
        " toward a certain, specified target. The following statements are social media posts expressing opinions about entities.\n"
        "Each statement can either be 'PRO' or 'CON' toward their associated entity.\n"
        "entity: Atheism\n"
        "statement: Leaving Christianity enables you to love the people you once rejected. #freethinker #Christianity #SemST\n"
        "stance: PRO\n"
        "entity: Feminist Movement\n"
        "statement: Always a delight to see chest-drumming alpha males hiss and scuttle backwards up the wall when a feminist enters the room. #manly #SemST\n"
        "stance: PRO\n"
        "entity: Christianity\n"
        "statement: AlharbiF I’ll bomb anything I can get my hands on, especially if THEY aren’t christian. #graham2016 #GOP #SemST\n"
        "stance: CON\n"
        "entity: Hillary Clinton\n"
        "statement: Would you wanna be in a long term relationship with some bitch that hides her emails, & lies to your face? Then #Dontvote #SemST\n"
        "stance: CON\n"
        "Analyze the following statement and determine its stance towards the entity.\n"
        "Respond with a single word: 'PRO' or 'CON'. Only return the stance as a single word, and no other text.'\n"
        f"statement:\n{essay}\n"
        "stance:"
    )

# standalone stance classifier
def stance_classifier(text):
    prompt = get_stance_prompt(text)
    response = query_ollama(prompt, model="mistral")

    response_upper = response.upper()
    if 'CON' in response_upper:
        return stance_mapping['CON']
    elif 'PRO' in response_upper:
        return stance_mapping['PRO']
    elif 'NEUTRAL' in response_upper:
        return stance_mapping['NEUTRAL']
    else:
        return None  # unclear
# Out:
# /Users/alejandro/Library/Mobile Documents/com~apple~CloudDocs/Exeter/Season 3/StyleOverSubstance/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer

# load tokenizer and model weights
model_name = 's-nlp/deberta-large-formality-ranker'
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

id2formality = {0: "formal", 1: "informal"}

# standalone formality classifier
def formality_classifier(text, threshold=0.50):
    # tokenization
    encoding = tokenizer(
        text,
        add_special_tokens=True,
        return_token_type_ids=True,
        truncation=True,
        padding="max_length",
        return_tensors="pt",
    )

    # get output
    output = model(**encoding)
    scores = output.logits.softmax(dim=1)[0]  # get first (and only) row

    # get score
    formality_score = {id2formality[idx]: score.item() for idx, score in enumerate(scores)}

    # apply a threshold
    if formality_score['formal'] > threshold:
        return 0  # formal
    elif formality_score['informal'] > threshold:
        return 1  # informal
    else:
        return None  # uncertain

# %%
from transformers import pipeline
sentiment_analysis = pipeline("sentiment-analysis",model="siebert/sentiment-roberta-large-english")

# standalone sentiment classifier
def sentiment_classifier(text, threshold=0.90):
    # run classifier
    result = sentiment_analysis(text, truncation=True, max_length=512)[0]

    label = result['label']
    score = result['score']

    # apply a threshold
    if label == 'POSITIVE' and score > threshold:
        return 0  # positive
    elif label == 'NEGATIVE' and score > threshold:
        return 1  # negative
    else:
        return None  # uncertain
# Out:
# Device set to use cpu

# %% [markdown]
# ### Generation

# %%
# dictionaries to be used in the prompt

RUBRIC = """
- SCORE OF 6: An essay in this category demonstrates clear and consistent mastery, although it may have a few minor errors. A typical essay effectively and insightfully develops a point of view on the issue and demonstrates outstanding critical thinking, using clearly appropriate examples, reasons, and other evidence to support its position; the essay is well organized and clearly focused, demonstrating clear coherence and smooth progression of ideas; the essay exhibits skillful use of language, using a varied, accurate, and apt vocabulary and demonstrates meaningful variety in sentence structure; the essay is free of most errors in grammar, usage, and mechanics.
- SCORE OF 5: An essay in this category demonstrates reasonably consistent mastery, although it will have occasional errors or lapses in quality. A typical essay effectively develops a point of view on the issue and demonstrates strong critical thinking, generally using appropriate examples, reasons, and other evidence to support its position; the essay is well organized and focused, demonstrating coherence and progression of ideas; the essay exhibits facility in the use of language, using appropriate vocabulary demonstrates variety in sentence structure; the essay is generally free of most errors in grammar, usage, and mechanics.
- SCORE OF 4: An essay in this category demonstrates adequate mastery, although it will have lapses in quality. A typical essay develops a point of view on the issue and demonstrates competent critical thinking, using adequate examples, reasons, and other evidence to support its position; the essay is generally organized and focused, demonstrating some coherence and progression of ideas exhibits adequate; the essay may demonstrate inconsistent facility in the use of language, using generally appropriate vocabulary demonstrates some variety in sentence structure; the essay may have some errors in grammar, usage, and mechanics.
- SCORE OF 3: An essay in this category demonstrates developing mastery, and is marked by ONE OR MORE of the following weaknesses: develops a point of view on the issue, demonstrating some critical thinking, but may do so inconsistently or use inadequate examples, reasons, or other evidence to support its position; the essay is limited in its organization or focus, or may demonstrate some lapses in coherence or progression of ideas displays; the essay may demonstrate facility in the use of language, but sometimes uses weak vocabulary or inappropriate word choice and/or lacks variety or demonstrates problems in sentence structure; the essay may contain an accumulation of errors in grammar, usage, and mechanics.
- SCORE OF 2: An essay in this category demonstrates little mastery, and is flawed by ONE OR MORE of the following weaknesses: develops a point of view on the issue that is vague or seriously limited, and demonstrates weak critical thinking, providing inappropriate or insufficient examples, reasons, or other evidence to support its position; the essay is poorly organized and/or focused, or demonstrates serious problems with coherence or progression of ideas; the essay displays very little facility in the use of language, using very limited vocabulary or incorrect word choice and/or demonstrates frequent problems in sentence structure; the essay contains errors in grammar, usage, and mechanics so serious that meaning is somewhat obscured.
- SCORE OF 1: An essay in this category demonstrates very little or no mastery, and is severely flawed by ONE OR MORE of the following weaknesses: develops no viable point of view on the issue, or provides little or no evidence to support its position; the essay is disorganized or unfocused, resulting in a disjointed or incoherent essay; the essay displays fundamental errors in vocabulary and/or demonstrates severe flaws in sentence structure; the essay contains pervasive errors in grammar, usage, or mechanics that persistently interfere with meaning.
"""

stance_opposite = {
    'PRO': 'CON',
    'CON': 'PRO',
}

formality_opposite = {
    'FORMAL': 'INFORMAL',
    'INFORMAL': 'FORMAL'
}

sentiment_opposite = {
    'POSITIVE': 'NEGATIVE',
    'NEGATIVE': 'POSITIVE'
}

attribute_context = {
    'stance': (
        "In a PRO stance, the author clearly supports the topic by providing strong reasons in favor of it, emphasizing benefits, positives, and supportive arguments.\n"
        "In a CON stance, the author clearly opposes the topic, focusing on drawbacks, risks, or negative consequences.\n"
        "Switching stance requires presenting the OPPOSITE arguments.\n"
    ),
    'formality': (
        "FORMAL writing is structured and objective. It uses academic language, avoids contractions (like 'don't' or 'can't'), and avoids casual expressions.\n"
        "It favors complex sentences, third-person point of view, and professional tone.\n"
        "INFORMAL writing is conversational, uses contractions and casual language, favors first-person or second-person, and may include slang or simple sentence structures.\n"
        "To change from FORMAL to INFORMAL, make the writing sound more like spoken language. Use really simple, repeated words and structures, expressions. Use contractions and slang terms. \n"
        "To change from INFORMAL to FORMAL, eliminate contractions, use more precise vocabulary, and avoid casual phrasing.\n"
    ),
    'sentiment': (
        "POSITIVE sentiment expresses approval, optimism, or positive feelings.\n"
        "NEGATIVE sentiment expresses disapproval, criticism, or negative feelings.\n"
    )
}

# function to build the counterfactual prompt to be fed to the LLM
def get_counterfactual_prompt(text, attribute, original_label, og_score):
    if attribute == 'stance':
        opposite_label = stance_opposite.get(original_label, "UNKNOWN")
        instruction = f"the current stance is {original_label}. Change it to {opposite_label}"
    elif attribute == 'formality':
        opposite_label = formality_opposite.get(original_label, "UNKNOWN")
        instruction = f"the current style is '{original_label}'. Change it to {opposite_label}."
    elif attribute == 'sentiment':
        opposite_label = sentiment_opposite.get(original_label, "UNKNOWN")
        instruction = f"the current sentiment is '{original_label}'. Change it to {opposite_label}."
    else:
        instruction = "Unknown attribute."

    return (
        "You are a skilled editor. Your task is to rewrite the following essay carefully."
        f"Keep the structure, arguments, and topic the same, but {instruction}. "
        f"Context:\n{attribute_context[attribute]}\n\n"
        "Do not add new ideas or remove key points. Keep the length and organization similar.\n"
        "Keep the same level of language proficiency from the original essay, including misspellings, punctuation and capitalization.\n"
        f"This essay has a score of {og_score} points on a 6-point scale. Your rewriting must meet the exact criteria as the rubric details for a score of {og_score}. The marking rubric is defined as follows:\n{RUBRIC}\n\n"
        "Respond with the rewritten essay only.\n\n"
        f"Essay:\n{text}"
    )

# generates a counterfactual given text, attribute, original label and the essay score
def generate_counterfactual(text, attribute, original_label, og_score):
    prompt = get_counterfactual_prompt(text, attribute, original_label, og_score)
    response = query_ollama(prompt, model="gemma3:12b", temperature=0.7)
    return response

# %%
import random

# generates x amount of counterfactuals and validates them using the given attribute classifier.
# essays are discarded if they do not align with correct classification.
# uses stratified sampling by holistic_essay_score attribute
def collect_validated_flips(
    df,
    attribute: str,                   # 'stance', 'formality', or 'sentiment'
    from_class: int,                  # e.g., 0 (for PRO)
    classifier_fn=None,               # e.g., stance_classifier
    label_mapping=None,               # e.g., {'PRO': 0, 'CON': 1, 'NEUTRAL': 2}
    prefix="ST",                      # e.g., 'ST'
    target_count=100
):

    # reverse the label mapping
    reverse_label_mapping = {v: k for k, v in label_mapping.items()}

    from_label = reverse_label_mapping[from_class]
    to_label = {
        'stance': stance_opposite,
        'formality': formality_opposite,
        'sentiment': sentiment_opposite
    }[attribute][from_label]
    to_class = label_mapping[to_label]

    successful_flips = []

    # stratified ssampling by score
    score_bins = {score: group.index.tolist() for score, group in df.groupby('holistic_essay_score')}
    bin_targets = {score: max(1, int(len(indices) / len(df) * target_count)) for score, indices in score_bins.items()}

    total_flips = 0 # count total flips
    total_attempts = 1
    for score, indices in score_bins.items():
        if total_flips >= target_count:
            print(f"Done. Total flips is {total_flips} out of {target_count}")
            break

        random.shuffle(indices)
        sample_count = 0

        for idx in indices:
            if sample_count >= bin_targets[score]:
                break

            row = df.loc[idx]
            if row[attribute] != from_class:
                continue

            original_text = row['full_text']
            essay_code_original = f"{idx}-O"
            og_score = row['holistic_essay_score']

            # generate counterfactual
            print(f"----- Attempt: {total_attempts} -----")
            try:
                print(f"Generating counterfactual... Attribute: {attribute}. {from_label} -> {to_label}")
                flipped_text = generate_counterfactual(original_text, attribute, from_label, og_score)
                print("Counterfactual generated.")
                new_label = classifier_fn(flipped_text)
                print(f"New label: {reverse_label_mapping[new_label]}")
            except Exception as e:
                print(f"[!] Error at idx {idx}: {e}")
                continue

            print(f"Flip Attempt: {from_label} → {to_label} | Classified as: {new_label}")

            if new_label == to_class:
                print("✓ - Correctly generated!")
                essay_code_cf = f"{idx}-C{prefix}"

                successful_flips.append({
                    "essay_code": essay_code_original,
                    "full_text": original_text,
                    "attribute": attribute,
                    "label": from_class,
                    "score_og": row['holistic_essay_score']
                })

                successful_flips.append({
                    "essay_code": essay_code_cf,
                    "full_text": flipped_text,
                    "attribute": attribute,
                    "label": to_class,
                    "score_og": row['holistic_essay_score']
                })

                sample_count += 1
                total_flips += 1
            else:
                print("X - Incorrectly generated!")
            total_attempts += 1

            if len(successful_flips) >= target_count * 2:
                break

    print("---------------------------------------")
    print(f"Generated {total_flips} counterfactuals with {total_attempts - 1} attempts.")

    # second pass to fill counterfactuals if target not reached
    if total_flips < target_count:
        print(f"\nSecond pass: filling {target_count - total_flips} missing flips...")

        remaining_indices = df[df[attribute] == from_class].index.tolist()
        random.shuffle(remaining_indices)

        for idx in remaining_indices:
            if total_flips >= target_count:
                break

            row = df.loc[idx]
            original_text = row['full_text']
            essay_code_original = f"{idx}-O"
            og_score = row['holistic_essay_score']

            print(f"----- Attempt: {total_attempts} -----")
            try:
                print(f"Generating counterfactual... Attribute: {attribute}. {from_label} -> {to_label}")
                flipped_text = generate_counterfactual(original_text, attribute, from_label, og_score)
                print("Counterfactual generated.")
                new_label = classifier_fn(flipped_text)
                print(f"New label: {reverse_label_mapping[new_label]}")
            except Exception as e:
                print(f"[!] Error at idx {idx}: {e}")
                continue

            print(f"Flip Attempt: {from_label} → {to_label} | Classified as: {new_label}")

            if new_label == to_class:
                print("✓ - Correctly generated!")
                essay_code_cf = f"{idx}-C{prefix}"

                successful_flips.append({
                    "essay_code": essay_code_original,
                    "full_text": original_text,
                    "attribute": attribute,
                    "label": from_class,
                    "score_og": row['holistic_essay_score']
                })

                successful_flips.append({
                    "essay_code": essay_code_cf,
                    "full_text": flipped_text,
                    "attribute": attribute,
                    "label": to_class,
                    "score_og": row['holistic_essay_score']
                })

                total_flips += 1
            else:
                print("X - Incorrectly generated!")
            total_attempts += 1

    print(f"Generated {total_flips} counterfactuals")

    return pd.DataFrame(successful_flips)

# %%
# generate PRO -> CON flipped stance counterfactuals

stance_pro_to_con_df = collect_validated_flips(
    df=df,
    attribute="stance",
    from_class=0,  # PRO
    classifier_fn=stance_classifier,
    label_mapping={"PRO": 0, "CON": 1, "NEUTRAL": 2},
    prefix="ST",
    target_count=100
)

stance_pro_to_con_df
# Out:
# ----- Attempt: 1 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 2 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 3 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 4 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 5 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 6 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 7 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 8 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 9 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 10 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 11 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 12 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: PRO
# Flip Attempt: PRO → CON | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 13 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 14 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 15 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 16 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 17 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 18 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 19 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 20 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 21 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 22 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 23 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 24 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 25 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 26 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 27 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 28 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: PRO → CON | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 29 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: PRO
# Flip Attempt: PRO → CON | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 30 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 31 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 32 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 33 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 34 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 35 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 36 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 37 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 38 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 39 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: PRO
# Flip Attempt: PRO → CON | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 40 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 41 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 42 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 43 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 44 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 45 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 46 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 47 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 48 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 49 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 50 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 51 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 52 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 53 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 54 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 55 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 56 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: PRO
# Flip Attempt: PRO → CON | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 57 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 58 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 59 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 60 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: PRO → CON | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 61 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: PRO
# Flip Attempt: PRO → CON | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 62 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 63 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 64 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: PRO
# Flip Attempt: PRO → CON | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 65 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 66 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: PRO
# Flip Attempt: PRO → CON | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 67 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 68 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 69 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 70 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 71 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 72 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 73 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 74 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 75 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 76 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 77 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 78 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 79 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 80 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 81 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 82 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: PRO
# Flip Attempt: PRO → CON | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 83 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 84 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 85 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 86 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: PRO
# Flip Attempt: PRO → CON | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 87 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: PRO
# Flip Attempt: PRO → CON | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 88 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 89 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 90 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 91 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 92 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 93 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 94 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 95 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 96 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 97 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 98 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 99 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 100 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 101 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 102 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 103 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 104 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 105 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 106 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 107 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 108 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 109 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ---------------------------------------
# Generated 97 counterfactuals with 109 attempts.
#
# Second pass: filling 3 missing flips...
# ----- Attempt: 110 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 111 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 112 -----
# Generating counterfactual... Attribute: stance. PRO -> CON
# Counterfactual generated.
# New label: CON
# Flip Attempt: PRO → CON | Classified as: 1
# ✓ - Correctly generated!
# Generated 100 counterfactuals
#     essay_code                                          full_text attribute  \
# 0      15984-O  i would try to do better in school so i would ...    stance
# 1    15984-CST  i would try to do worse in school so i would n...    stance
# 2       1972-O  cars have been producing smog and causing prob...    stance
# 3     1972-CST  cars have been producing smog and causing prob...    stance
# 4      10486-O  im going to tell you if the facial action codi...    stance
# ..         ...                                                ...       ...
# 195   2854-CST  do you think you could live without your car, ...    stance
# 196     6896-O  at every school there are extracurricular acti...    stance
# 197   6896-CST  at every school there are extracurricular acti...    stance
# 198    14704-O  dear principal,\r\n\r\ni have heard around tha...    stance
# 199  14704-CST  dear principal,\n\ni have heard around that yo...    stance
#
#      label  score_og
# 0        0         1
# 1        1         1
# 2        0         1
# 3        1         1
# 4        0         1
# ..     ...       ...
# 195      1         3
# 196      0         4
# 197      1         4
# 198      0         4
# 199      1         4
#
# [200 rows x 5 columns]

# %%
# generate CON -> PRO flipped stance counterfactuals

stance_con_to_pro_df = collect_validated_flips(
    df=df,
    attribute="stance",
    from_class=1,  # CON
    classifier_fn=stance_classifier,
    label_mapping={"PRO": 0, "CON": 1, "NEUTRAL": 2},
    prefix="ST",
    target_count=100
)

stance_con_to_pro_df
# Out:
# ----- Attempt: 1 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 2 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 3 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 4 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 5 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 6 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 7 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 8 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 9 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 10 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 11 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 12 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 13 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 14 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 15 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: CON → PRO | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 16 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 17 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 18 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 19 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 20 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 21 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 22 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 23 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 24 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 25 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 26 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 27 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 28 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 29 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 30 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 31 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 32 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 33 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 34 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 35 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 36 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 37 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 38 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 39 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 40 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 41 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 42 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 43 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 44 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 45 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: CON → PRO | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 46 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 47 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 48 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 49 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 50 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 51 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 52 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 53 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 54 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 55 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 56 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 57 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 58 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 59 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 60 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 61 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 62 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 63 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 64 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 65 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 66 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 67 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 68 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: CON → PRO | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 69 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 70 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 71 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 72 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 73 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: CON → PRO | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 74 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 75 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 76 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 77 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 78 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 79 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 80 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 81 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 82 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 83 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: CON → PRO | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 84 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 85 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 86 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 87 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 88 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 89 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 90 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 91 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 92 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 93 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 94 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 95 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 96 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 97 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 98 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 99 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 100 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 101 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 102 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: NEUTRAL
# Flip Attempt: CON → PRO | Classified as: 2
# X - Incorrectly generated!
# ----- Attempt: 103 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 104 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 105 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 106 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 107 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 108 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 109 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 110 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 111 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 112 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 113 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 114 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 115 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 116 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 117 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 118 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 119 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 120 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 121 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 122 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 123 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: CON
# Flip Attempt: CON → PRO | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 124 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 125 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 126 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 127 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ---------------------------------------
# Generated 97 counterfactuals with 127 attempts.
#
# Second pass: filling 3 missing flips...
# ----- Attempt: 128 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 129 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 130 -----
# Generating counterfactual... Attribute: stance. CON -> PRO
# Counterfactual generated.
# New label: PRO
# Flip Attempt: CON → PRO | Classified as: 0
# ✓ - Correctly generated!
# Generated 100 counterfactuals
#     essay_code                                          full_text attribute  \
# 0       8603-O  studying venus is something that you would hav...    stance
# 1     8603-CST  studying venus is something that you absolutel...    stance
# 2      18824-O  the electoral college is a way of voting for p...    stance
# 3    18824-CST  the electoral college is a way of voting for p...    stance
# 4      19381-O  i think we should keep the electoral collage b...    stance
# ..         ...                                                ...       ...
# 195   3623-CST  summer projects are a great way to keep studen...    stance
# 196    15235-O  dear principal,\r\n\r\ni believe that having a...    stance
# 197  15235-CST  dear principal,\n\ni believe that having a b a...    stance
# 198      994-O  phones and driving\r\n\r\nalthough cell phones...    stance
# 199    994-CST  phones and driving\n\nalthough cell phones hav...    stance
#
#      label  score_og
# 0        1         1
# 1        0         1
# 2        1         1
# 3        0         1
# 4        1         1
# ..     ...       ...
# 195      0         5
# 196      1         4
# 197      0         4
# 198      1         3
# 199      0         3
#
# [200 rows x 5 columns]

# %%
# generate POSITIVE -> NEGATIVE flipped sentiment counterfactuals

sentiment_positive_to_negative_df = collect_validated_flips(
    df=df,
    attribute="sentiment",
    from_class=0,  # POSITIVE
    classifier_fn=sentiment_classifier,
    label_mapping={"POSITIVE": 0, "NEGATIVE": 1},
    prefix="SE",
    target_count=100
)

sentiment_positive_to_negative_df
# Out:
# ----- Attempt: 1 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 2 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 3 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 4 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 5 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 6 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 7 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 8 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 9 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 10 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 11 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 12 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 13 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 14 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 15 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 16 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 17 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 18 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 19 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 20 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 21 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 22 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 23 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 24 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 25 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 26 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 27 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 28 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 29 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 30 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 31 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 32 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 33 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 34 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 35 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 36 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 37 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 38 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 39 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 40 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 41 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 42 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 43 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 44 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 45 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 46 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 47 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 48 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 49 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 50 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 51 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 52 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 53 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 54 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 55 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 56 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 57 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 58 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 59 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 60 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 61 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 62 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 63 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 64 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 65 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 66 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 67 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 68 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 69 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 70 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 71 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 72 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 73 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 74 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 75 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 76 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 77 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 78 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 79 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 80 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 81 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 82 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 83 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 84 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 85 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 86 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 87 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 88 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 89 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 90 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 91 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 92 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 93 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 94 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 95 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 96 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 97 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 98 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 99 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# [!] Error at idx 24724: None
# ----- Attempt: 99 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 100 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 101 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 102 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 103 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 104 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 105 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 106 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 107 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 108 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 109 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 110 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ---------------------------------------
# Generated 97 counterfactuals with 110 attempts.
#
# Second pass: filling 3 missing flips...
# ----- Attempt: 111 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 112 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 113 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 114 -----
# Generating counterfactual... Attribute: sentiment. POSITIVE -> NEGATIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: POSITIVE → NEGATIVE | Classified as: 1
# ✓ - Correctly generated!
# Generated 100 counterfactuals
#     essay_code                                          full_text  attribute  \
# 0       5756-O  luke bomberger was just a normal high school g...  sentiment
# 1     5756-CSE  luke bomberger was just a normal high school g...  sentiment
# 2       8842-O  because he said the sun is more colse from us ...  sentiment
# 3     8842-CSE  because he insisted the sun was more colse fro...  sentiment
# 4      11281-O  i'm fore the value of using this technology to...  sentiment
# ..         ...                                                ...        ...
# 195   5892-CSE  luke is decidedly not courageous because he jo...  sentiment
# 196    16245-O  i personally believe that driverless cars are ...  sentiment
# 197  16245-CSE  i personally believe that driverless cars are ...  sentiment
# 198    16939-O  the further development of driverless cars sho...  sentiment
# 199  16939-CSE  the further development of driverless cars sho...  sentiment
#
#      label  score_og
# 0        0         1
# 1        1         1
# 2        0         1
# 3        1         1
# 4        0         1
# ..     ...       ...
# 195      1         1
# 196      0         3
# 197      1         3
# 198      0         5
# 199      1         5
#
# [200 rows x 5 columns]

# %%
# generate NEGATIVE -> POSITIVE flipped sentiment counterfactuals

sentiment_negative_to_positive_df = collect_validated_flips(
    df=df,
    attribute="sentiment",
    from_class=1,  # NEGATIVE
    classifier_fn=sentiment_classifier,
    label_mapping={"POSITIVE": 0, "NEGATIVE": 1},
    prefix="SE",
    target_count=100
)

sentiment_negative_to_positive_df
# Out:
# ----- Attempt: 1 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 2 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 3 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 4 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 5 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 6 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 7 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 8 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 9 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 10 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 11 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 12 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 13 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 14 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 15 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 16 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 17 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 18 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 19 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 20 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 21 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 22 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 23 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 24 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 25 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 26 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 27 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 28 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 29 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 30 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 31 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 32 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 33 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 34 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 35 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 36 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 37 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 38 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 39 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 40 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 41 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 42 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 43 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 44 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 45 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 46 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 47 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 48 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 49 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 50 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 51 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 52 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 53 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 54 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 55 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 56 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 57 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 58 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 59 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 60 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 61 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 62 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 63 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 64 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 65 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 66 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 67 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 68 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 69 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 70 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 71 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 72 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 73 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 74 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 75 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 76 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 77 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 78 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 79 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 80 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 81 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 82 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 83 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 84 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 85 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 86 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 87 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 88 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 89 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 90 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 91 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 92 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 93 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 94 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 95 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 96 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 97 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: NEGATIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 1
# X - Incorrectly generated!
# ----- Attempt: 98 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 99 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 100 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ---------------------------------------
# Generated 97 counterfactuals with 100 attempts.
#
# Second pass: filling 3 missing flips...
# ----- Attempt: 101 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 102 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 103 -----
# Generating counterfactual... Attribute: sentiment. NEGATIVE -> POSITIVE
# Counterfactual generated.
# New label: POSITIVE
# Flip Attempt: NEGATIVE → POSITIVE | Classified as: 0
# ✓ - Correctly generated!
# Generated 100 counterfactuals
#     essay_code                                          full_text  attribute  \
# 0       1451-O  no one is evan going to read these things so t...  sentiment
# 1     1451-CSE  no one is evan going to read these things so t...  sentiment
# 2      23542-O  do you think student would benefit from being ...  sentiment
# 3    23542-CSE  do you think student would benefit from being ...  sentiment
# 4       8311-O  -\r\n\r\nvenus is an second planet for the sun...  sentiment
# ..         ...                                                ...        ...
# 195  17151-CSE  driverless cars are coming to the roads and th...  sentiment
# 196     7663-O  the article "the challenge of exploring venus"...  sentiment
# 197   7663-CSE  the article "the challenge of exploring venus"...  sentiment
# 198     6606-O  have you ever done something you didn't want t...  sentiment
# 199   6606-CSE  have you ever done something you *loved* to do...  sentiment
#
#      label  score_og
# 0        1         1
# 1        0         1
# 2        1         1
# 3        0         1
# 4        1         1
# ..     ...       ...
# 195      0         2
# 196      1         4
# 197      0         4
# 198      1         4
# 199      0         4
#
# [200 rows x 5 columns]

# %%
# generate FORMAL -> INFORMAL flipped formality counterfactuals

formality_formal_to_informal_df = collect_validated_flips(
    df=df,
    attribute="formality",
    from_class=0,  # FORMAL
    classifier_fn=formality_classifier,
    label_mapping={"FORMAL": 0, "INFORMAL": 1},
    prefix="FO",
    target_count=100
)

formality_formal_to_informal_df
# Out:
# ----- Attempt: 1 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 2 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 3 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 4 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 5 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 6 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 7 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 8 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 9 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 10 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 11 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 12 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 13 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 14 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 15 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 16 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 17 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 18 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 19 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 20 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 21 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 22 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 23 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 24 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 25 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 26 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 27 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 28 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 29 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 30 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 31 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 32 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 33 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 34 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 35 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 36 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 37 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 38 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 39 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 40 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 41 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 42 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 43 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 44 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 45 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 46 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 47 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 48 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 49 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 50 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 51 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 52 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 53 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 54 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 55 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 56 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 57 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 58 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 59 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 60 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 61 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 62 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 63 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 64 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 65 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 66 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 67 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 68 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 69 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 70 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 71 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 72 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 73 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 74 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 75 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 76 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 77 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 78 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 79 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 80 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 81 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 82 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 83 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 84 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 85 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 86 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 87 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 88 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 89 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 90 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 91 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 92 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 93 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 94 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 95 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 96 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 97 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 98 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 99 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 100 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 101 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 102 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 103 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 104 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 105 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 106 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 107 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 108 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 109 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 110 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 111 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 112 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 113 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 114 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 115 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 116 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 117 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 118 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 119 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 120 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 121 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 122 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 123 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 124 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 125 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 126 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 127 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 128 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 129 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 130 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 131 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 132 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 133 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 134 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 135 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 136 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 137 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 138 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 139 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 140 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 141 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 142 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 143 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 144 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 145 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 146 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 147 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 148 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 149 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 150 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 151 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 152 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 153 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 154 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 155 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 156 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 157 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 158 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 159 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 160 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 161 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 162 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 163 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 164 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 165 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 166 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 167 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 168 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 169 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 170 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 171 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 172 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 173 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 174 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ---------------------------------------
# Generated 97 counterfactuals with 174 attempts.
#
# Second pass: filling 3 missing flips...
# ----- Attempt: 175 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 176 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 177 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# ----- Attempt: 178 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 0
# X - Incorrectly generated!
# ----- Attempt: 179 -----
# Generating counterfactual... Attribute: formality. FORMAL -> INFORMAL
# Counterfactual generated.
# New label: INFORMAL
# Flip Attempt: FORMAL → INFORMAL | Classified as: 1
# ✓ - Correctly generated!
# Generated 100 counterfactuals
#     essay_code                                          full_text  attribute  \
# 0       1278-O  the selctions i just read contain one common s...  formality
# 1     1278-CFO  the stuff i just read all talks about one thin...  formality
# 2      12401-O  many people might think that the face on mars ...  formality
# 3    12401-CFO  a lot of folks think the face on Mars was made...  formality
# 4       9316-O  in "the challenge of exploring venus," the aut...  formality
# ..         ...                                                ...        ...
# 195   4896-CFO  in the story "a cowboy who rode the waves" it ...  formality
# 196    24883-O  why is it impirtant to have multiple people gi...  formality
# 197  24883-CFO  why is it impirtant to have multiple people gi...  formality
# 198    22572-O  do you think that students would benefit from ...  formality
# 199  22572-CFO  do you think that students would benefit from ...  formality
#
#      label  score_og
# 0        0         1
# 1        1         1
# 2        0         1
# 3        1         1
# 4        0         1
# ..     ...       ...
# 195      1         4
# 196      0         3
# 197      1         3
# 198      0         3
# 199      1         3
#
# [200 rows x 5 columns]

# %%
# generate INFORMAL -> FORMAL flipped formality counterfactuals

formality_informal_to_formal_df = collect_validated_flips(
    df=df,
    attribute="formality",
    from_class=1,  # INFORMAL
    classifier_fn=formality_classifier,
    label_mapping={"FORMAL": 0, "INFORMAL": 1},
    prefix="FO",
    target_count=100
)

formality_informal_to_formal_df
# Out:
# ----- Attempt: 1 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 2 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 3 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 4 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 5 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 6 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 7 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 8 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 9 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 10 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 11 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 12 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 13 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 14 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 15 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 16 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 17 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 18 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 19 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 20 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 21 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 22 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 23 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 24 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 25 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 26 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 27 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 28 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 29 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 30 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 31 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 32 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 33 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 34 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 35 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 36 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 37 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 38 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 39 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 40 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 41 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 42 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 43 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 44 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 45 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 46 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 47 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 48 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 49 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 50 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 51 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 52 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 53 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 54 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 55 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 56 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 57 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 58 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 59 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 60 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 61 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 62 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 63 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 64 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 65 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 66 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 67 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 68 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 69 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 70 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 71 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 72 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 73 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 74 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 75 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 76 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 77 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 78 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 79 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 80 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 81 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 82 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 83 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 84 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 85 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 86 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 87 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 88 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 89 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 90 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 91 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 92 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 93 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 94 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 95 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 96 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 97 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ---------------------------------------
# Generated 97 counterfactuals with 97 attempts.
#
# Second pass: filling 3 missing flips...
# ----- Attempt: 98 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 99 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# ----- Attempt: 100 -----
# Generating counterfactual... Attribute: formality. INFORMAL -> FORMAL
# Counterfactual generated.
# New label: FORMAL
# Flip Attempt: INFORMAL → FORMAL | Classified as: 0
# ✓ - Correctly generated!
# Generated 100 counterfactuals
#     essay_code                                          full_text  attribute  \
# 0       1859-O  the passage "in german suburb, life goes on wi...  formality
# 1     1859-CFO  The passage "in german suburb, life goes on wi...  formality
# 2      19152-O  to me i think we should change the election by...  formality
# 3    19152-CFO  To me, I believe that we should alter the elec...  formality
# 4       8542-O  the challenge of exploring venus\r\n\r\non thi...  formality
# ..         ...                                                ...        ...
# 195  18967-CFO  candidate, what do you think when I say that w...  formality
# 196    19652-O  dear senator of state,\r\n\r\ni think keeping ...  formality
# 197  19652-CFO  Dear Senator of State,\n\nI believe that maint...  formality
# 198     9618-O  you are smile, but you only 80 percent happy, ...  formality
# 199   9618-CFO  You appear to be smiling, but analysis indicat...  formality
#
#      label  score_og
# 0        1         1
# 1        0         1
# 2        1         1
# 3        0         1
# 4        1         1
# ..     ...       ...
# 195      0         1
# 196      1         1
# 197      0         1
# 198      1         3
# 199      0         3
#
# [200 rows x 5 columns]

# %%
import os

# save counterfactuals to its folder
os.makedirs("counterfactuals", exist_ok=True)

stance_pro_to_con_df.to_csv("counterfactuals/stance_pro_to_con.csv", index=False)
stance_con_to_pro_df.to_csv("counterfactuals/stance_con_to_pro.csv", index=False)

sentiment_positive_to_negative_df.to_csv("counterfactuals/sentiment_positive_to_negative.csv", index=False)
sentiment_negative_to_positive_df.to_csv("counterfactuals/sentiment_negative_to_positive.csv", index=False)

formality_formal_to_informal_df.to_csv("counterfactuals/formality_formal_to_informal.csv", index=False)
formality_informal_to_formal_df.to_csv("counterfactuals/formality_informal_to_formal.csv", index=False)
